# %% [markdown]
# 1. What is the purpose of a PivotTable in Excel.
#
#     Answer-> The purpose of a PivotTable in Excel is to summarize, analyze, and present large amounts of data quickly and easily without changing the original dataset.
#
#
# 2. Create a PivotTable to show Total Sales by Region.
#
#     Answer-> ![image.png](data:image/png;base64,...).
#
#  3. Apply Conditional Formatting to highlight sales greater than 400.
#     Answer-> ![image.png](data:image/png;base64,...).
#
# 4. Explain the difference between Sorting and Filtering with an example from this dataset.
#
#     Answer-> Sorting- Sorting changes the order of data based on a selected column, but does not hide any data.
#
#     Filtering-Filtering hides data that does not meet specific criteria, without changing the original order permanently.
#     we have applied custom sort than apply ascending to descending or A to Z.
#
# 5. Create a PivotChart showing Monthly Sales Trend.
#
#     Answer-> IN a pivot table Drag Date to the rows area,Drag Sales to the Values area ensure it shows Sum of Sales and go to Insert → PivotChart,
#     Choose Line Chart (best for trends).
#
# 6. Use a Slicer to filter data by Product and observe changes in sales.
#
#     Answer-> The slicer acts as an interactive filter, making it easy to Analyze sales per product,Compare trends visually,Create dynamic dashboards and after applying the slicer in the given dataset we found the PRODUCTS- APPLE,MANGOES,ORANGES.
#
# 7. Why are Dashboards important for decision-making in business analysis?
#
#     Answer-> Dashboards are important for decision-making in business analysis because they turn raw data into clear, actionable insights that managers and analysts can understand quickly.This helps businesses respond quickly to changes, risks, or opportunities.Dashboards highlight critical KPIs aligned with business goals.
#
# 8. Create a Dashboard that includes:
#
#     Answer-> . Sales by Region (PivotTable + Chart)
#     after applying sales by region i found the pivot chart & table which shows ROW LABELS-> EAST-467,WEST-347,NORTH-2518,SOUTH-3497 and the shows the highest candle in west.
#     . Product Filter (Slicer)
#     after applying slicer in a product it shows or given the result like- APPLE,MANGOES,ORANGES.
#     . Monthly Trend (Line Chart)
#     IT shows uptrend in the chart.
#
# 9. Group dates in the PivotTable into Months and calculate the average sales per month.
#
#     Answer-> average sales per month like- jan-320.25,feb-344,march-319.333,april-385,may-428.6667,june-279.25.
#
#
# 10. Combine Apples and Oranges into one group called Fruits and compare its sales with other products.
#
#     Answer-> combine the apple and oranges in the group called group 1 if i compare its sales it should be FRUITS-4308,MANGOES-2521,TOTAL-6829.
